# %% [markdown]
# # tsetmc

# %% [markdown]
# ## import

# %%
import requests
import pandas as pd
import numpy as np
import json
import re
from datetime import datetime

# %% [markdown]
# ## Data

# %%
import requests
import pandas as pd


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}
r = requests.get('https://old.tsetmc.com/tsev2/data/MarketWatchPlus.aspx', headers=headers)
main_text = r.text
main_text
# Out:
# "169005,1221503,557054@02/10/16 17:35:09,F,2153710.60,<div class='mn'>(1523.75)</div> -0.07%,75082547066041928.00,7510895688.00,53845520333996.00,401946,F,5654889059.00,210900286484045.00,237571,F,11370682.00,1316790140775.00,40561,@40456523152045946,IRO9AGAH0371,ضترو1100,اختيارخ ص آگاه-7500-02/11/15,154225,4270,4276,4290,3,14,59860000,4270,4290,4275,,1,1716,3,68,500000.00,1.00,1000,311,,15;68267250263823360,IRO9AGAH0381,ضترو1101,اختيارخ ص آگاه-8000-02/11/15,105229,3760,3760,3760,1,10,37600000,3760,3760,3839,,1,133,3,68,500000.00,1.00,1000,311,,43;44281549758033199,IRO9AGAH0391,ضترو1102,اختيارخ ص آگاه-9000-02/11/15,61044,0,3050,3050,0,0,0,0,0,3050,,1,1695,3,68,500000.00,1.00,1000,311,,42;53599516658560363,IRO9AGAH0401,ضترو1103,اختيارخ ص آگاه-10000-02/11/15,61044,0,1500,1500,0,0,0,0,0,1500,,1,1661,3,68,500000.00,1.00,1000,311,,6;41112149796224903,IRO9AGAH0411,ضترو1104,اختيارخ ص آگاه-11000-02/11/15,61044,0,1,1,0,0,0,0,0,1,,1,1056,3,68,500000.00,1.00,1000,311,,0;61279242158640689,IRO9AGAH0431,ضترو1106,اختيارخ ص آگاه-13000-02/11/15,61044,0,300,300,0,0,0,0,0,300,,1,136,3,68,500000.00,1.00,1000,311,,33;13369851645626082,IRO9AHRM2001,ضهرم3009,اختيارخ اهرم-26000-1403/03/23,61044,0,1,1,0,0,0,0,0,1,,1,137,3,68,500000.00,1.00,1000,311,,0;67525074308235540,IRO9AHRM2011,ضهرم3010,اختيارخ اهرم-28000-1403/03/23,61044,0,2551,2551,0,0,0,0,0,2551,,1,2564,3,68,500000.00,1.00,1000,311,,68;24389446800799045,IRO9AHRM6481,ضهرم1217,اختيارخ اهرم-11000-1402/12/23,121054,9058,9836,10500,17,93,914745000,9052,10500,10124,,1,1805,3,68,500000.00,1.00,1000,311,,6238;26778517035268247,IRO9AHRM6491,ضهرم1218,اختيارخ اهرم-12000-1402/12/23,114907,10000,9978,8008,5,102,1017797000,8008,10000,9716,,1,158,3,68,500000.00,1.00,1000,311,,9472;5541536729025349,IRO9AHRM6501,ضهرم1219,اختيارخ اهرم-13000-1402/12/23,145924,8160,8301,8697,499,7207,59825585000,8000,8795,8410,,1,2222,3,68,500000.00,1.00,1000,311,,323624;55949825883649292,IRO9AHRM6511,ضهرم1220,اختيارخ اهرم-14000-1402/12/23,61044,0,7481,7408,0,0,0,0,0,7481,,1,148,3,68,500000.00,1.00,1000,311,,34006;54011329794405893,IRO9AHRM6521,ضهرم1221,اختيارخ اهرم-15000-1402/12/23,61044,0,7499,7499,0,0,0,0,0,7499,,1,1704,3,68,500000.00,1.00,1000,311,,7563;39050522752860763,IRO9AHRM6531,ضهرم1222,اختيارخ اهرم-16000-1402/12/23,142413,5155,5696,5840,32,1120,6379472000,5155,6280,5702,,1,1728,3,68,500000.00,1.00,1000,311,,44628;2260974911561023,IRO9AHRM6541,ضهرم1223,اختيارخ اهرم-18000-1402/12/23,143349,4000,3955,4033,75,1549,6126640000,3503,4191,4053,,1,285,3,68,500000.00,1.00,1000,311,,70406;19266862956139223,IRO9AHRM6551,ضهرم1224,اختيارخ اهرم-20000-1402/12/23,154436,2211,2643,2771,752,21821,57678866000,2211,3000,2795,,1,650,3,68,500000.00,1.00,1000,311,,262447;6135867755924038,IRO9AHRM6561,ضهرم1225,اختيارخ اهرم-22000-1402/12/23,145957,1600,1648,1717,264,4229,6969841000,1402,1854,1721,,1,1358,3,68,500000.00,1.00,1000,311,,83090;12577673899600996,IRO9AHRM6581,ضهرم1227,اختيارخ اهرم-26000-1402/12/23,144725,650,667,670,73,1713,1142642000,600,785,702,,1,156,3,68,500000.00,1.00,1000,311,,28072;42780287876795888,IRO9AHRM6591,ضهرم1228,اختيارخ اهرم-28000-1402/12/23,135144,420,421,455,17,377,158847000,400,500,476,,1,163,3,68,500000.00,1.00,1000,311,,72014;66467474443792820,IRO9AHRM6631,ضهرم1229,اختيارخ اهرم-30000-1402/12/23,115808,180,268,344,8,27,7240000,180,344,164,,1,1258,3,68,500000.00,1.00,1000,311,,6096;9431925711725149,IRO9AHRM6641,ضهرم1230,اختيارخ اهرم-34000-1402/12/23,95334,390,390,390,2,44,17160000,390,390,399,,1,1196,3,68,500000.00,1.00,1000,311,,11310;44831961878164445,IRO9AHRM6671,ضهرم1231,اختيارخ اهرم-38000-1402/12/23,61044,0,511,534,0,0,0,0,0,511,,1,1268,3,68,500000.00,1.00,1000,311,,6199;47516975268580153,IRO9AHRM6681,ضهرم1232,اختيارخ اهرم-42000-1402/12/23,61044,0,220,221,0,0,0,0,0,220,,1,1178,3,68,500000.00,1.00,1000,311,,9017;41876389060511395,IRO9AHRM6701,ضهرم0101,اختيارخ اهرم-13000-1403/01/22,61044,0,1,1,0,0,0,0,0,1,,1,912,3,68,500000.00,1.00,1000,311,,0;5326213430763898,IRO9AHRM6711,ضهرم0102,اختيارخ اهرم-14000-1403/01/22,6 ...

# %%
df_main = pd.DataFrame((main_text.split('@')[2]).split(';'))
df_main
# Out:
#                                                       0
# 0     40456523152045946,IRO9AGAH0371,ضترو1100,اختيار...
# 1     68267250263823360,IRO9AGAH0381,ضترو1101,اختيار...
# 2     44281549758033199,IRO9AGAH0391,ضترو1102,اختيار...
# 3     53599516658560363,IRO9AGAH0401,ضترو1103,اختيار...
# 4     41112149796224903,IRO9AGAH0411,ضترو1104,اختيار...
# ...                                                 ...
# 1993  70766443960930830,IRT1BHIN0002,بهين رو2,صندوق ...
# 1994  71073665530007809,IRB4O04403A1,اراد142,مرابحه ...
# 1995  71505526197848013,IRO9SARV8561,ضسرو0306,اختيار...
# 1996  71843282162462661,IRT3KARF0001,كارا,صندوق س. ك...
# 1997  71957984642204570,IRO7APTP0001,شپترو,پتروشيمي ...
#
# [1998 rows x 1 columns]

# %%
df_split = df_main[0].str.split(',',expand=True)
df_split
# Out:
#                      0             1         2   \
# 0     40456523152045946  IRO9AGAH0371  ضترو1100
# 1     68267250263823360  IRO9AGAH0381  ضترو1101
# 2     44281549758033199  IRO9AGAH0391  ضترو1102
# 3     53599516658560363  IRO9AGAH0401  ضترو1103
# 4     41112149796224903  IRO9AGAH0411  ضترو1104
# ...                 ...           ...       ...
# 1993  70766443960930830  IRT1BHIN0002  بهين رو2
# 1994  71073665530007809  IRB4O04403A1   اراد142
# 1995  71505526197848013  IRO9SARV8561  ضسرو0306
# 1996  71843282162462661  IRT3KARF0001      كارا
# 1997  71957984642204570  IRO7APTP0001     شپترو
#
#                                  3       4       5       6       7     8   \
# 0      اختيارخ ص آگاه-7500-02/11/15  154225    4270    4276    4290     3
# 1      اختيارخ ص آگاه-8000-02/11/15  105229    3760    3760    3760     1
# 2      اختيارخ ص آگاه-9000-02/11/15   61044       0    3050    3050     0
# 3     اختيارخ ص آگاه-10000-02/11/15   61044       0    1500    1500     0
# 4     اختيارخ ص آگاه-11000-02/11/15   61044       0       1       1     0
# ...                             ...     ...     ...     ...     ...   ...
# 1993        صندوق س بهين خودرو-بخشي  145157       1       1       1    22
# 1994   مرابحه عام دولت142-ش.خ031009  145808  975000  975000  975000     5
# 1995  اختيارخ سرو-130000-1403/03/09   61044       0   25300   25300     0
# 1996               صندوق س. كارا -د  152101   16578   16578   16578  3022
# 1997                پتروشيمي آبادان  122941    1780    1795    1792   176
#
#              9   ... 15    16 17  18          19         20           21   22  \
# 0            14  ...  1  1716  3  68   500000.00       1.00         1000  311
# 1            10  ...  1   133  3  68   500000.00       1.00         1000  311
# 2             0  ...  1  1695  3  68   500000.00       1.00         1000  311
# 3             0  ...  1  1661  3  68   500000.00       1.00         1000  311
# 4             0  ...  1  1056  3  68   500000.00       1.00         1000  311
# ...         ...  ... ..   ... ..  ..         ...        ...          ...  ...
# 1993    9300000  ...  1   116  1  68        1.00       1.00    500000000  305
# 1994    4960000  ...  1   194  2  69  1023010.00  925590.00     50000000  706
# 1995          0  ...  1  1315  3  68   500000.00       1.00           10  311
# 1996  274429370  ...  1  3351  2  68    18214.00   14904.00    100000000  305
# 1997    5546037  ...  1  2176  4  44     1855.00    1747.00  10000000000  309
#
#             23   24
# 0                15
# 1                43
# 2                42
# 3                 6
# 4                 0
# ...        ...  ...
# 1993
# 1994
# 1995            523
# 1996  16582.00
# 1997
#
# [1998 rows x 25 columns]

# %%
df_split[2].values
# Out:
# array(['ضترو1100', 'ضترو1101', 'ضترو1102', ..., 'ضسرو0306', 'كارا',
#        'شپترو'], dtype=object)

# %%
0,"id"
1,"id_info"
2,"نماد"
3,"نام نماد"
4,"?"
5,"اولین"
6,"پایانی"
7,"معامله"
8,"تعداد معاملات"
9,"حجم معاملات"
10,"ارزش معاملات"
11,"کمترین بازه روز"
12,"بیشترین بازه روز"
13,"بازده دیروز"
14,"EPS"
15,"حجم مبنا"
16, "?"
17,"?"
18,"کد گروه صنعت"
19,"قیمت مجاز بیشترین"
20,"قیمت مجاز کمترین"
21,"تعداد سهام"
22,"?"
23,"NAV ابطال"
24,"موقعیت های باز"
# Out:
# (24, 'موقعیت های باز')

# %%
col = ["id", "id_info", "نماد", "نام نماد", "?", "اولین", "پایانی", "معامله", "تعداد معاملات", "حجم معاملات", "ارزش معاملات", "کمترین بازه روز", "بیشترین بازه روز",
       "بازده دیروز", "EPS", "حجم مبنا", "?", "?", "کد گروه صنعت", "قیمت مجاز بیشترین", "قیمت مجاز کمترین", "تعداد سهام", "?", "NAV ابطال", "موقعیت های باز"]

df = df_split.copy()

for i in range(len(col)):
    df.rename(columns={i:f"{col[i]}"}, inplace=True)

df
# Out:
#                      id       id_info      نماد  \
# 0     40456523152045946  IRO9AGAH0371  ضترو1100
# 1     68267250263823360  IRO9AGAH0381  ضترو1101
# 2     44281549758033199  IRO9AGAH0391  ضترو1102
# 3     53599516658560363  IRO9AGAH0401  ضترو1103
# 4     41112149796224903  IRO9AGAH0411  ضترو1104
# ...                 ...           ...       ...
# 1993  70766443960930830  IRT1BHIN0002  بهين رو2
# 1994  71073665530007809  IRB4O04403A1   اراد142
# 1995  71505526197848013  IRO9SARV8561  ضسرو0306
# 1996  71843282162462661  IRT3KARF0001      كارا
# 1997  71957984642204570  IRO7APTP0001     شپترو
#
#                            نام نماد       ?   اولین  پایانی  معامله  \
# 0      اختيارخ ص آگاه-7500-02/11/15  154225    4270    4276    4290
# 1      اختيارخ ص آگاه-8000-02/11/15  105229    3760    3760    3760
# 2      اختيارخ ص آگاه-9000-02/11/15   61044       0    3050    3050
# 3     اختيارخ ص آگاه-10000-02/11/15   61044       0    1500    1500
# 4     اختيارخ ص آگاه-11000-02/11/15   61044       0       1       1
# ...                             ...     ...     ...     ...     ...
# 1993        صندوق س بهين خودرو-بخشي  145157       1       1       1
# 1994   مرابحه عام دولت142-ش.خ031009  145808  975000  975000  975000
# 1995  اختيارخ سرو-130000-1403/03/09   61044       0   25300   25300
# 1996               صندوق س. كارا -د  152101   16578   16578   16578
# 1997                پتروشيمي آبادان  122941    1780    1795    1792
#
#      تعداد معاملات حجم معاملات  ... حجم مبنا     ?  ? کد گروه صنعت  \
# 0                3          14  ...        1  1716  3           68
# 1                1          10  ...        1   133  3           68
# 2                0           0  ...        1  1695  3           68
# 3                0           0  ...        1  1661  3           68
# 4                0           0  ...        1  1056  3           68
# ...            ...         ...  ...      ...   ... ..          ...
# 1993            22     9300000  ...        1   116  1           68
# 1994             5     4960000  ...        1   194  2           69
# 1995             0           0  ...        1  1315  3           68
# 1996          3022   274429370  ...        1  3351  2           68
# 1997           176     5546037  ...        1  2176  4           44
#
#      قیمت مجاز بیشترین قیمت مجاز کمترین   تعداد سهام    ? NAV ابطال  \
# 0            500000.00             1.00         1000  311
# 1            500000.00             1.00         1000  311
# 2            500000.00             1.00         1000  311
# 3            500000.00             1.00         1000  311
# 4            500000.00             1.00         1000  311
# ...                ...              ...          ...  ...       ...
# 1993              1.00             1.00    500000000  305
# 1994        1023010.00        925590.00     50000000  706
# 1995         500000.00             1.00           10  311
# 1996          18214.00         14904.00    100000000  305  16582.00
# 1997           1855.00          1747.00  10000000000  309
#
#      موقعیت های باز
# 0                15
# 1                43
# 2                42
# 3                 6
# 4                 0
# ...             ...
# 1993
# 1994
# 1995            523
# 1996
# 1997
#
# [1998 rows x 25 columns]

# %%
df_ektiar = df[df["نام نماد"].apply(lambda x:"اختيار" in x)].reset_index(drop=True)
# df_ektiar
df_ektiar.to_excel(r"../tsetmc/Data/df_ektiar.xlsx")
df_ektiar
# Out:
#                     id       id_info        نماد  \
# 0    40456523152045946  IRO9AGAH0371    ضترو1100
# 1    68267250263823360  IRO9AGAH0381    ضترو1101
# 2    44281549758033199  IRO9AGAH0391    ضترو1102
# 3    53599516658560363  IRO9AGAH0401    ضترو1103
# 4    41112149796224903  IRO9AGAH0411    ضترو1104
# ..                 ...           ...         ...
# 613  64320695157374475  IRO9FOLD8611    ضفلا0102
# 614  64482999142461383  IROATHRP2231  ضبتهران306
# 615  65456567251643758  IROAIKDP2791    ضخاور133
# 616  67616762120421356  IRO9AHRM6691    ضهرم0100
# 617  71505526197848013  IRO9SARV8561    ضسرو0306
#
#                           نام نماد       ? اولین پایانی معامله تعداد معاملات  \
# 0     اختيارخ ص آگاه-7500-02/11/15  154225  4270   4276   4290             3
# 1     اختيارخ ص آگاه-8000-02/11/15  105229  3760   3760   3760             1
# 2     اختيارخ ص آگاه-9000-02/11/15   61044     0   3050   3050             0
# 3    اختيارخ ص آگاه-10000-02/11/15   61044     0   1500   1500             0
# 4    اختيارخ ص آگاه-11000-02/11/15   61044     0      1      1             0
# ..                             ...     ...   ...    ...    ...           ...
# 613  اختيارخ فولاد-5000-1403/01/26   61044     0   1561   1560             0
# 614   اختيارخ بتهران-2900-14030320   61210     0      1      1             0
# 615     اختيارخ خاور-2680-14030115   61210     0      1      1             0
# 616  اختيارخ اهرم-12000-1403/01/22   61044     0      1      1             0
# 617  اختيارخ سرو-130000-1403/03/09   61044     0  25300  25300             0
#
#     حجم معاملات  ... حجم مبنا     ?  ? کد گروه صنعت قیمت مجاز بیشترین  \
# 0            14  ...        1  1716  3           68         500000.00
# 1            10  ...        1   133  3           68         500000.00
# 2             0  ...        1  1695  3           68         500000.00
# 3             0  ...        1  1661  3           68         500000.00
# 4             0  ...        1  1056  3           68         500000.00
# ..          ...  ...      ...   ... ..          ...               ...
# 613           0  ...        1  1011  3           27         100000.00
# 614           0  ...        1    94  3           66        1000000.00
# 615           0  ...        1   124  3           34        1000000.00
# 616           0  ...        1   127  3           68         500000.00
# 617           0  ...        1  1315  3           68         500000.00
#
#     قیمت مجاز کمترین تعداد سهام    ? NAV ابطال موقعیت های باز
# 0               1.00       1000  311                       15
# 1               1.00       1000  311                       43
# 2               1.00       1000  311                       42
# 3               1.00       1000  311                        6
# 4               1.00       1000  311                        0
# ..               ...        ...  ...       ...            ...
# 613             1.00       1000  311                       23
# 614             1.00       1000  320                        0
# 615             1.00       1000  320                        0
# 616             1.00       1000  311                        0
# 617             1.00         10  311                      523
#
# [618 rows x 25 columns]

# %%
df_split_values= df_ektiar["نام نماد"].str.split('-')
df_ektiar["نام نماد"] = df_split_values.str[0]
df_ektiar["مقدار"] = df_split_values.str[1]
df_ektiar["تاریخ"] = df_split_values.str[2]
df_ektiar.insert(3, "نام نماد", df_ektiar.pop("نام نماد"))
df_ektiar.insert(4, "مقدار", df_ektiar.pop("مقدار"))
df_ektiar.insert(5, "تاریخ", df_ektiar.pop("تاریخ"))

#df_ektiar = df_ektiar.drop(columns=["نام نماد"])
# df_ektiar.to_excel(r"..\tsetmc\df_ektiar.xlsx")
df_ektiar
# Out:
#                     id       id_info        نماد        نام نماد   مقدار  \
# 0    40456523152045946  IRO9AGAH0371    ضترو1100  اختيارخ ص آگاه    7500
# 1    68267250263823360  IRO9AGAH0381    ضترو1101  اختيارخ ص آگاه    8000
# 2    44281549758033199  IRO9AGAH0391    ضترو1102  اختيارخ ص آگاه    9000
# 3    53599516658560363  IRO9AGAH0401    ضترو1103  اختيارخ ص آگاه   10000
# 4    41112149796224903  IRO9AGAH0411    ضترو1104  اختيارخ ص آگاه   11000
# ..                 ...           ...         ...             ...     ...
# 613  64320695157374475  IRO9FOLD8611    ضفلا0102   اختيارخ فولاد    5000
# 614  64482999142461383  IROATHRP2231  ضبتهران306  اختيارخ بتهران    2900
# 615  65456567251643758  IROAIKDP2791    ضخاور133    اختيارخ خاور    2680
# 616  67616762120421356  IRO9AHRM6691    ضهرم0100    اختيارخ اهرم   12000
# 617  71505526197848013  IRO9SARV8561    ضسرو0306     اختيارخ سرو  130000
#
#           تاریخ       ? اولین پایانی معامله  ... حجم مبنا     ?  ?  \
# 0      02/11/15  154225  4270   4276   4290  ...        1  1716  3
# 1      02/11/15  105229  3760   3760   3760  ...        1   133  3
# 2      02/11/15   61044     0   3050   3050  ...        1  1695  3
# 3      02/11/15   61044     0   1500   1500  ...        1  1661  3
# 4      02/11/15   61044     0      1      1  ...        1  1056  3
# ..          ...     ...   ...    ...    ...  ...      ...   ... ..
# 613  1403/01/26   61044     0   1561   1560  ...        1  1011  3
# 614    14030320   61210     0      1      1  ...        1    94  3
# 615    14030115   61210     0      1      1  ...        1   124  3
# 616  1403/01/22   61044     0      1      1  ...        1   127  3
# 617  1403/03/09   61044     0  25300  25300  ...        1  1315  3
#
#     کد گروه صنعت قیمت مجاز بیشترین قیمت مجاز کمترین تعداد سهام    ? NAV ابطال  \
# 0             68         500000.00             1.00       1000  311
# 1             68         500000.00             1.00       1000  311
# 2             68         500000.00             1.00       1000  311
# 3             68         500000.00             1.00       1000  311
# 4             68         500000.00             1.00       1000  311
# ..           ...               ...              ...        ...  ...       ...
# 613           27         100000.00             1.00       1000  311
# 614           66        1000000.00             1.00       1000  320
# 615           34        1000000.00             1.00       1000  320
# 616           68         500000.00             1.00       1000  311
# 617           68         500000.00             1.00         10  311
#
#     موقعیت های باز
# 0               15
# 1               43
# 2               42
# 3                6
# 4                0
# ..             ...
# 613             23
# 614              0
# 615              0
# 616              0
# 617            523
#
# [618 rows x 27 columns]

# %%
def convert_time(time):
    if len(time) == 8 and '/' not in time:
        year = int(time[:4])
        month = int(time[4:6])
        day = int(time[6:])
        return f"{year}/{month:02d}/{day:02d}"
    else:
        return time

# def convert_year(time):
#     time_split = time.split('/')
#     if len(time_split) == 6:
#         year = int(time_split[:2])
#         month = int(time_split[2:4])
#         day = int(time_split[4:])
#         return f"14{year}/{month:02d}/{day:02d}"
#     else:
#         return time
   
df_ektiar['تاریخ'] = df_ektiar['تاریخ'].apply(convert_time)
# df_ektiar['تاریخ'] = df_ektiar['تاریخ'].apply(convert_year)

df_ektiar
# Out:
#                     id       id_info        نماد        نام نماد   مقدار  \
# 0    40456523152045946  IRO9AGAH0371    ضترو1100  اختيارخ ص آگاه    7500
# 1    68267250263823360  IRO9AGAH0381    ضترو1101  اختيارخ ص آگاه    8000
# 2    44281549758033199  IRO9AGAH0391    ضترو1102  اختيارخ ص آگاه    9000
# 3    53599516658560363  IRO9AGAH0401    ضترو1103  اختيارخ ص آگاه   10000
# 4    41112149796224903  IRO9AGAH0411    ضترو1104  اختيارخ ص آگاه   11000
# ..                 ...           ...         ...             ...     ...
# 613  64320695157374475  IRO9FOLD8611    ضفلا0102   اختيارخ فولاد    5000
# 614  64482999142461383  IROATHRP2231  ضبتهران306  اختيارخ بتهران    2900
# 615  65456567251643758  IROAIKDP2791    ضخاور133    اختيارخ خاور    2680
# 616  67616762120421356  IRO9AHRM6691    ضهرم0100    اختيارخ اهرم   12000
# 617  71505526197848013  IRO9SARV8561    ضسرو0306     اختيارخ سرو  130000
#
#           تاریخ       ? اولین پایانی معامله  ... حجم مبنا     ?  ?  \
# 0      02/11/15  154225  4270   4276   4290  ...        1  1716  3
# 1      02/11/15  105229  3760   3760   3760  ...        1   133  3
# 2      02/11/15   61044     0   3050   3050  ...        1  1695  3
# 3      02/11/15   61044     0   1500   1500  ...        1  1661  3
# 4      02/11/15   61044     0      1      1  ...        1  1056  3
# ..          ...     ...   ...    ...    ...  ...      ...   ... ..
# 613  1403/01/26   61044     0   1561   1560  ...        1  1011  3
# 614  1403/03/20   61210     0      1      1  ...        1    94  3
# 615  1403/01/15   61210     0      1      1  ...        1   124  3
# 616  1403/01/22   61044     0      1      1  ...        1   127  3
# 617  1403/03/09   61044     0  25300  25300  ...        1  1315  3
#
#     کد گروه صنعت قیمت مجاز بیشترین قیمت مجاز کمترین تعداد سهام    ? NAV ابطال  \
# 0             68         500000.00             1.00       1000  311
# 1             68         500000.00             1.00       1000  311
# 2             68         500000.00             1.00       1000  311
# 3             68         500000.00             1.00       1000  311
# 4             68         500000.00             1.00       1000  311
# ..           ...               ...              ...        ...  ...       ...
# 613           27         100000.00             1.00       1000  311
# 614           66        1000000.00             1.00       1000  320
# 615           34        1000000.00             1.00       1000  320
# 616           68         500000.00             1.00       1000  311
# 617           68         500000.00             1.00         10  311
#
#     موقعیت های باز
# 0               15
# 1               43
# 2               42
# 3                6
# 4                0
# ..             ...
# 613             23
# 614              0
# 615              0
# 616              0
# 617            523
#
# [618 rows x 27 columns]

# %%
df_ektiar["وضعیت"] = np.where(df_ektiar["نام نماد"].str.contains("اختيارخ"), 'خرید', 'فروش')
df_ektiar.insert(5, "وضعیت", df_ektiar.pop("وضعیت"))
print("---> split buy_sell <---")
df_ektiar
# Out:
# ---> split buy_sell <---
#                     id       id_info        نماد        نام نماد   مقدار  \
# 0    40456523152045946  IRO9AGAH0371    ضترو1100  اختيارخ ص آگاه    7500
# 1    68267250263823360  IRO9AGAH0381    ضترو1101  اختيارخ ص آگاه    8000
# 2    44281549758033199  IRO9AGAH0391    ضترو1102  اختيارخ ص آگاه    9000
# 3    53599516658560363  IRO9AGAH0401    ضترو1103  اختيارخ ص آگاه   10000
# 4    41112149796224903  IRO9AGAH0411    ضترو1104  اختيارخ ص آگاه   11000
# ..                 ...           ...         ...             ...     ...
# 613  64320695157374475  IRO9FOLD8611    ضفلا0102   اختيارخ فولاد    5000
# 614  64482999142461383  IROATHRP2231  ضبتهران306  اختيارخ بتهران    2900
# 615  65456567251643758  IROAIKDP2791    ضخاور133    اختيارخ خاور    2680
# 616  67616762120421356  IRO9AHRM6691    ضهرم0100    اختيارخ اهرم   12000
# 617  71505526197848013  IRO9SARV8561    ضسرو0306     اختيارخ سرو  130000
#
#     وضعیت       تاریخ       ? اولین پایانی  ... حجم مبنا     ?  ?  \
# 0    خرید    02/11/15  154225  4270   4276  ...        1  1716  3
# 1    خرید    02/11/15  105229  3760   3760  ...        1   133  3
# 2    خرید    02/11/15   61044     0   3050  ...        1  1695  3
# 3    خرید    02/11/15   61044     0   1500  ...        1  1661  3
# 4    خرید    02/11/15   61044     0      1  ...        1  1056  3
# ..    ...         ...     ...   ...    ...  ...      ...   ... ..
# 613  خرید  1403/01/26   61044     0   1561  ...        1  1011  3
# 614  خرید  1403/03/20   61210     0      1  ...        1    94  3
# 615  خرید  1403/01/15   61210     0      1  ...        1   124  3
# 616  خرید  1403/01/22   61044     0      1  ...        1   127  3
# 617  خرید  1403/03/09   61044     0  25300  ...        1  1315  3
#
#     کد گروه صنعت قیمت مجاز بیشترین قیمت مجاز کمترین تعداد سهام    ? NAV ابطال  \
# 0             68         500000.00             1.00       1000  311
# 1             68         500000.00             1.00       1000  311
# 2             68         500000.00             1.00       1000  311
# 3             68         500000.00             1.00       1000  311
# 4             68         500000.00             1.00       1000  311
# ..           ...               ...              ...        ...  ...       ...
# 613           27         100000.00             1.00       1000  311
# 614           66        1000000.00             1.00       1000  320
# 615           34        1000000.00             1.00       1000  320
# 616           68         500000.00             1.00       1000  311
# 617           68         500000.00             1.00         10  311
#
#     موقعیت های باز
# 0               15
# 1               43
# 2               42
# 3                6
# 4                0
# ..             ...
# 613             23
# 614              0
# 615              0
# 616              0
# 617            523
#
# [618 rows x 28 columns]

# %%
count_values = df_ektiar['وضعیت'].value_counts()
buy_count = count_values.get('خرید', 0)
sell_count = count_values.get('فروش', 0)
sell_count
# Out:
# 45

# %%
df_ektiar['تاریخ']
# Out:
# 0        02/11/15
# 1        02/11/15
# 2        02/11/15
# 3        02/11/15
# 4        02/11/15
#           ...
# 613    1403/01/26
# 614    1403/03/20
# 615    1403/01/15
# 616    1403/01/22
# 617    1403/03/09
# Name: تاریخ, Length: 618, dtype: object

# %%
df_tsetmc = df[df["نام نماد"].apply(lambda x:"اختيار" not in x)].reset_index(drop=True)
df_tsetmc.reset_index(drop=True)
df_tsetmc.to_excel(r"..\tsetmc\df_tsetmc.xlsx")

# %% [markdown]
# ## Clean Data

# %%
df_tsetmc.replace("",np.nan,inplace=True)
df_ektiar.replace("",np.nan,inplace=True)
df_ektiar
# Out:
#                     id       id_info      نماد  \
# 0    40456523152045946  IRO9AGAH0371  ضترو1100
# 1    68267250263823360  IRO9AGAH0381  ضترو1101
# 2    53599516658560363  IRO9AGAH0401  ضترو1103
# 3    41112149796224903  IRO9AGAH0411  ضترو1104
# 4    13369851645626082  IRO9AHRM2001  ضهرم3009
# ..                 ...           ...       ...
# 608  49915757809309158  IRO9PTEH4071  ضترا1157
# 609  51291811866521004  IRO9BHIN4221  ضهين0309
# 610  51842468910459742  IRO9PTEH4031  ضترا1153
# 611  54075020788283417  IRO9SARV8471  ضسرو1026
# 612  54779792954979665  IRO9TAMN8091  ضستا1118
#
#                            نام نماد       ? اولین پایانی معامله تعداد معاملات  \
# 0      اختيارخ ص آگاه-7500-02/11/15   61029     0   3750   3750             0
# 1      اختيارخ ص آگاه-8000-02/11/15   61029     0   3920   3950             0
# 2     اختيارخ ص آگاه-10000-02/11/15   61029     0   1500   1500             0
# 3     اختيارخ ص آگاه-11000-02/11/15   61029     0      1      1             0
# 4     اختيارخ اهرم-26000-1403/03/23   61029     0      1      1             0
# ..                              ...     ...   ...    ...    ...           ...
# 608   اختيارخ شتران-5000-1402/11/23  122859    50     11     10             2
# 609  اختيارخ بهين رو-15000-03/03/30  105911   400    474    330             4
# 610   اختيارخ شتران-3500-1402/11/23   61029     0   1167   1150             0
# 611   اختيارخ سرو-180000-1402/10/06   61029     0      1      1             0
# 612    اختيارخ شستا-1700-1402/11/11   61029     0      1      1             0
#
#     حجم معاملات  ... بازده دیروز EPS حجم مبنا     ?  ? کد گروه صنعت  \
# 0             0  ...        3750 NaN        1  2288  3           68
# 1             0  ...        3920 NaN        1   155  3           68
# 2             0  ...        1500 NaN        1  2269  3           68
# 3             0  ...           1 NaN        1   252  3           68
# 4             0  ...           1 NaN        1   168  3           68
# ..          ...  ...         ...  ..      ...   ... ..          ...
# 608        1020  ...          21 NaN        1  1199  3           23
# 609          20  ...         545 NaN        1   146  3           68
# 610           0  ...        1167 NaN        1   711  3           23
# 611           0  ...           1 NaN        1    38  3           68
# 612           0  ...           1 NaN        1   336  3           39
#
#     قیمت مجاز بیشترین قیمت مجاز کمترین تعداد سهام    ?
# 0           500000.00             1.00       1000  311
# 1           500000.00             1.00       1000  311
# 2           500000.00             1.00       1000  311
# 3           500000.00             1.00       1000  311
# 4           500000.00             1.00       1000  311
# ..                ...              ...        ...  ...
# 608         100000.00             1.00       1000  311
# 609         500000.00             1.00       1000  311
# 610         100000.00             1.00       1000  311
# 611         500000.00             1.00         10  311
# 612         100000.00             1.00       1000  311
#
# [613 rows x 23 columns]

# %%
df_tsetmc.isna().sum()
# Out:
# id                   0
# id_info              0
# نماد                 0
# نام نماد             0
# ?                    0
# اولین                0
# پایانی               0
# معامله               0
# تعداد معاملات        0
# حجم معاملات          0
# ارزش معاملات         0
# کمترین بازه روز      0
# بیشترین بازه روز     0
# بازده دیروز          0
# EPS                  0
# حجم مبنا             0
# ?                    0
# ?                    0
# کد گروه صنعت         0
# قیمت مجاز بیشترین    0
# قیمت مجاز کمترین     0
# تعداد سهام           0
# ?                    0
# NAV ابطال            0
# موقعیت های باز       0
# dtype: int64

# %%
df_ektiar.isna().sum()
# Out:
# id                   0
# id_info              0
# نماد                 0
# نام نماد             0
# ?                    0
# اولین                0
# پایانی               0
# معامله               0
# تعداد معاملات        0
# حجم معاملات          0
# ارزش معاملات         0
# کمترین بازه روز      0
# بیشترین بازه روز     0
# بازده دیروز          0
# EPS                  0
# حجم مبنا             0
# ?                    0
# ?                    0
# کد گروه صنعت         0
# قیمت مجاز بیشترین    0
# قیمت مجاز کمترین     0
# تعداد سهام           0
# ?                    0
# NAV ابطال            0
# موقعیت های باز       0
# dtype: int64
